# %%
import pandas as pd

# %%
base = pd.read_csv("credito_sem_outliers.csv",sep = ';', encoding = 'cp860')

# %%
base.head()
# Out:
#   CHEQUEESPECIAL  USO_CREDITO                        HISTORICO_CREDITO  \
# 0             <0            6  cr╧Ática / outros de cr╬Ìdito existente
# 1     sem cheque           12                         existente e pago
# 2       0<=X<200           12                         existente e pago
# 3             <0           24                         existente e pago
# 4     sem cheque           24  cr╧Ática / outros de cr╬Ìdito existente
#
#        PROPOSITO  BALANCO_ATUAL       BALANCO_MEDIO_CREDITO EMPREGADO  LOCAL  \
# 0  Computador/TV           1169  nenhuma economia conhecida       >=7      4
# 1  Computador/TV           3059                      >=1000    4<=X<7      2
# 2  Computador/TV           1567                        <100    1<=X<4      1
# 3  Computador/TV           1282                  100<=X<500    1<=X<4      4
# 4  Computador/TV           2424  nenhuma economia conhecida       >=7      4
#
#           ESTADOCIVIL OUTRASFUNCOES  RESIDENCIADESDE       TIPOSBENS  IDADE  \
# 0  masculino solteiro        nenhum                4  bens imΓÊñveis     67
# 1   masculino div/sep        nenhum                4  bens imΓÊñveis     61
# 2         fem div/cas        nenhum                1           carro     22
# 3         fem div/cas        nenhum                2           carro     32
# 4  masculino solteiro        nenhum                4  seguro de vida     53
#
#   OUTROSPLANOSPGTO RESIDENCIA  CREDITOSEXISTENTES             EMPREGO  \
# 0           nenhum  prΓÊñpria                   2       especializado
# 1           nenhum  prΓÊñpria                   1  n╧Ço especializado
# 2           nenhum  prΓÊñpria                   1       especializado
# 3           nenhum  prΓÊñpria                   1  n╧Ço especializado
# 4           nenhum  prΓÊñpria                   2       especializado
#
#    DEPENDENTES TRABAESTRANGEIRO CLASSE
# 0            1              sim    bom
# 1            1              sim    bom
# 2            1              sim    bom
# 3            1              sim   ruim
# 4            1              sim    bom

# %%
X = base.iloc[:, 0:19].values
y = base.iloc[:, 19].values

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
X[:, 0] = labelencoder.fit_transform(X[:, 0])
X[:, 2] = labelencoder.fit_transform(X[:, 2])
X[:, 3] = labelencoder.fit_transform(X[:, 3])
X[:, 5] = labelencoder.fit_transform(X[:, 5])
X[:, 6] = labelencoder.fit_transform(X[:, 6])
X[:, 8] = labelencoder.fit_transform(X[:, 8])
X[:, 9] = labelencoder.fit_transform(X[:, 9])
X[:, 11] = labelencoder.fit_transform(X[:, 11])
X[:, 13] = labelencoder.fit_transform(X[:, 13])
X[:, 14] = labelencoder.fit_transform(X[:, 14])
X[:, 16] = labelencoder.fit_transform(X[:, 16])
X[:, 18] = labelencoder.fit_transform(X[:, 18])

# %%
from sklearn.model_selection import train_test_split
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, 
                                                                  test_size=0.3,
                                                                  random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
